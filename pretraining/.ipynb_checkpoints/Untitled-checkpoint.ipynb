# %%
import sys
import os
import cv2
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
curdir = os.path.abspath(os.path.curdir)
sys.path.append(os.path.join(os.path.dirname(curdir), 'tf_pose'))

# %%
from pycocotools.coco import COCO

# %%
dataset_path = '/home/dan/prj/datasets/coco'

# %%
coco = COCO(os.path.join(dataset_path, 'annotations/person_keypoints_val2017.json'))
# Out:
# loading annotations into memory...
# Done (t=0.22s)
# creating index...
# index created!

# %%
# get all images containing given categories, select one at random
catIds = coco.getCatIds(catNms=['person']);
imgIds = coco.getImgIds(catIds=catIds );
img_info = coco.loadImgs(imgIds[np.random.randint(0,len(imgIds))])[0]

# %%
print(img_info)
filename = img_info['file_name']
img = cv2.imread(os.path.join(dataset_path, 'val2017', filename))[:,:,::-1]
plt.imshow(img)
# Out:
# {'width': 478, 'date_captured': '2013-11-18 03:39:49', 'id': 16598, 'height': 640, 'flickr_url': 'http://farm6.staticflickr.com/5091/5391571396_41823477da_z.jpg', 'coco_url': 'http://images.cocodataset.org/val2017/000000016598.jpg', 'license': 3, 'file_name': '000000016598.jpg'}

# %%
img_info['id']
# Out:
# 16598

# %%
coco.getAnnIds(img_info['id'])
# Out:
# [430275]

# %%
annIds = coco.getAnnIds(imgIds=img_info['id'], catIds=catIds, iscrowd=None) #get annotations ids of the image
anns = coco.loadAnns(annIds) #get annotation infomation of that image

#show the annotation on the image.
plt.imshow(img); plt.axis('off')
coco.showAnns(anns)

# %%
contours = []
for ann in anns:
    if 'segmentation' in ann:
        if type(ann['segmentation']) == list:
            # polygon
            for seg in ann['segmentation']:
                poly = np.array(seg).reshape((-1, 1, 2)).astype(np.int32)
                contours.append(poly)

print(len(contours))
# Out:
# 1

# %%
plt.imshow(cv2.drawContours(img.copy(), contours, -1, (0, 0, 0), 3))

# %%
test = img.copy()
plt.imshow( cv2.drawContours(test, contours, -1, (128, 125, 10), -1) )

# %%
mask = cv2.inRange(test, (128, 125, 10), (128, 125, 10))

# %%
res = cv2.bitwise_and(img,img, mask= mask)
plt.imshow(res)

# %%
for i in dir(cv2):
    if 'Sobel' in i:
            print(i)
# Out:
# Sobel

# %%
gray_image = cv2.cvtColor(res, cv2.COLOR_RGB2GRAY)
plt.imshow(gray_image, cmap='gray')

# %% [markdown]
# #### Test 1

# %%
pre_image = gray_image.copy()

edges = cv2.Canny(pre_image,130,130)
edges = cv2.dilate(edges, None)

plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
# Out:
# (Text(0.5,1,'Edge Image'),
#  ([], <a list of 0 Text xticklabel objects>),
#  ([], <a list of 0 Text yticklabel objects>))

# %% [markdown]
# #### Test 2

# %%
pre_image = cv2.GaussianBlur(gray_image,(3,3),0)

# %%
laplacian = cv2.Laplacian(pre_image,cv2.CV_64F)
sobelx = cv2.Sobel(pre_image,cv2.CV_64F,1,0,ksize=5)  # x
sobely = cv2.Sobel(pre_image,cv2.CV_64F,0,1,ksize=5)  # y

ret,thresh1 = cv2.threshold(laplacian,15,255,cv2.THRESH_BINARY)

plt.subplot(2,2,1),plt.imshow(img,cmap = 'gray')
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,2),plt.imshow(thresh1,cmap = 'gray')
plt.title('Laplacian'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,3),plt.imshow(sobelx,cmap = 'gray')
plt.title('Sobel X'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,4),plt.imshow(sobely,cmap = 'gray')
plt.title('Sobel Y'), plt.xticks([]), plt.yticks([])

plt.show()

# %% [markdown]
# #### Test 3

# %%
gray_image = cv2.cvtColor(res, cv2.COLOR_RGB2GRAY)
plt.imshow(gray_image, cmap='gray')
sigma = 0.33
#---- apply automatic Canny edge detection using the computed median----
lower = int(max(0, (1.0 - sigma) * sigma))
upper = int(min(255, (1.0 + sigma) * sigma))
print('lower : ',lower, 'upper', upper)
edges = cv2.Canny(gray_image,130,130)
edges = cv2.dilate(edges, None)

plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
# Out:
# lower :  0 upper 0
# (Text(0.5,1,'Edge Image'),
#  ([], <a list of 0 Text xticklabel objects>),
#  ([], <a list of 0 Text yticklabel objects>))

# %%
laplacian = cv2.Laplacian(gray_image,cv2.CV_64F)
sobelx = cv2.Sobel(gray_image,cv2.CV_64F,1,0,ksize=5)
plt.imshow(laplacian, cmap='gray')

# %%
sobelx.max()
# Out:
# 9783.0

# %%
kernel = np.ones([4, 4], np.float32)/16
blur = cv2.filter2D(gray_image, -1, kernel)

laplacian = cv2.Laplacian(blur,cv2.CV_64F)
threshold = 5
laplacian[laplacian<threshold] = 0
laplacian[laplacian>threshold] = 255

laplacian = cv2.dilate(laplacian, None)
plt.imshow(laplacian, cmap='gray')

# %%
laplacian.max()
# Out:
# 302.0

# %%
s = img.copy()
gray_image = cv2.cvtColor(s, cv2.COLOR_RGB2GRAY)
plt.imshow(gray_image)
high_thresh, thresh_im = cv2.threshold(gray_image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
lowThresh = 0.5*high_thresh

edged = cv2.Canny(gray_image, lowThresh, high_thresh)

# %%
double otsu_thresold = Imgproc.threshold(mGray,edged,0,255, Imgproc.THRESH_OTSU);
Imgproc.Canny(mRgba, edged, otsu_thresold*0.5,otsu_thresold);

# %%
plt.imshow(edged)

# %%
s = img.copy()
plt.imshow(s)
res = cv2.bitwise_and(s,s, mask= mask)
gray_image = cv2.cvtColor(res, cv2.COLOR_RGB2GRAY)
v = np.median(gray_image)

sigma = 0.33
#---- apply automatic Canny edge detection using the computed median----
lower = int(max(0, (1.0 - sigma) * v))
upper = int(min(255, (1.0 + sigma) * v))
edged = cv2.Canny(gray_image, lower, upper)
cv2.imshow('Edges',edged)

# %%
plt.imshow(edged, cmap='gray')

# %%
gray_image = cv2.cvtColor(res, cv2.COLOR_RGB2GRAY)
blurred = cv2.GaussianBlur(gray_image, (3, 3), 0)
v = np.median(gray_image)

#---- apply automatic Canny edge detection using the computed median----
sigma=0.33
lower = int(max(0, (1.0 - sigma) * v))
upper = int(min(255, (1.0 + sigma) * v))
edged = cv2.Canny(blurred, 200, 201)
plt.imshow(edged, cmap='gray')
result, thresh = cv2.threshold(edge_mask,127,255,cv2.THRESH_BINARY_INV)

# %%
plt.imshow(edge_mask, cmap='gray')

# %%
result, thresh = cv2.threshold(edge_mask,127,255,cv2.THRESH_BINARY_INV)

# %%
plt.imshow(thresh, cmap='gray')

# %%
mean = np.mean(edgeImg);
# Zero any value that is less than mean. This reduces a lot of noise.
edgeImg[edgeImg <= mean] = 0;
